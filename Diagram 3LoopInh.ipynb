# %%
from math import *
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %% [markdown]
# # Function definition

# %%
def trucR(mini,maxi,step,tau,D):
    wlist = [] 
    Gtlist = []
    
    for w in np.arange(0.1, 60, 0.1):
        Gt=(3*w**2*tau**2-1)/(cos(w * D))
        Gtlist.append(Gt)
        wlist.append(w)
    return plt.plot(Gtlist,wlist,label='Delta:'+ str(D))

# %%
def trucC(mini,maxi,step,tau,D):
    iwlist = [] 
    iGtlist = []
    
    for iw in np.arange(0.1, 20, 0.1):
        iGt=(3*iw*tau)-(iw**3*tau**3)/sin(iw * D)
        iGtlist.append(iGt)
        iwlist.append(iw)
    return plt.plot(iGtlist,iwlist,label='Delta:'+ str(D))

# %% [markdown]
# # Plotting with Real & Complex part of equation

# %%
wlist = []
Gtlist = []

iwlist = []
iGtlist = []

iDeltalist=[]
Deltalist=[]

tau = 0.0005**3                      #(time constant)
Delta = 0.0070 + 0.0010 + 0.0005 #(delay)
 

for w in np.arange(0.1, 100, 0.1):
    Gt=(3*(w**2)*(tau**2)-1)/(cos(w*Delta))
    Gtlist.append(Gt)
    wlist.append(w)

# %%
for iw in np.arange(0.1, 100, 0.1):
    iGt = ((3*iw*tau)-((iw**3)*(tau**3))/sin(iw*Delta))
    iGtlist.append(iGt)
    iwlist.append(iw)
            
fig, axes = plt.subplots(1, 3,figsize=(20, 5))

axes[0].plot(Gtlist, wlist)
axes[0].set_title("resolution in R")
axes[0].set_ylabel('w')
axes[0].set_xlabel('Gt')


axes[1].plot(iGtlist, iwlist)
axes[1].set_title("Resolution in C")           
axes[1].set_ylabel('iw')
axes[1].set_xlabel('iGt')

axes[2].plot(iGtlist, iwlist)
axes[2].plot(Gtlist, wlist)
axes[2].set_ylabel('w')
axes[2].set_xlabel('Gt')
axes[2].set_title("Both");


plt.show()

# %% [markdown]
# # Plotting G with =/= Delta

# %%
for D in np.arange(0,0.015,0.001):
    trucR(0.1,10,0.1,0.0800,D)

plt.grid()
plt.title("Real equation")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

for q in np.arange(0.001,0.015,0.001):
    trucC(0.1,10,0.1,0.0800,q)

plt.grid()
plt.title("Complex equation")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# # Plotting w over Delta

# %% [markdown]
# # Gt=1.3
# wlist=[]
# iwlist=[]
#
# for w in np.arange(10, 62, 0.0001):
#     Delta = acos((3*w**2*tau**2-1)/Gt)*(1/w)
#     wlist.append(w)
#     Deltalist.append(Delta)
#
#
# for iw in np.arange(10, 22, 0.001):
#     iDelta = asin((3*iw*tau)-(iw**3*tau**3)/Gt)*(1/w)
#     iwlist.append(iw)
#     iDeltalist.append(iDelta)
#
# fig, axes = plt.subplots(1, 3,figsize=(20, 5))
#
# axes[0].plot(Deltalist,wlist)
# axes[0].set_title('dependency of w on the delay Delta - in R')
# axes[0].set_ylabel('w')
# axes[0].set_xlabel('Delta')
#
#
# axes[1].plot(iDeltalist,iwlist)
# axes[1].set_title('dependency of w on the delay Delta - in C')
# axes[1].set_ylabel('iw')
# axes[1].set_xlabel('iDelta')
#
# axes[2].plot(Deltalist,wlist)
# axes[2].plot(iDeltalist,iwlist)
# axes[2].set_ylabel('w')
# axes[2].set_xlabel('Delta')
# axes[2].set_title("Both");
#
#
# plt.show()

# %% [markdown]
# # Plotting G over Delta

# %%
w=50
iw=22

Deltalist=[]
Glist=[]

iDeltalist=[]
iGlist=[]

for Delta in np.arange(0.001, 0.1, 0.001):
    G = (3*w**2*tau**2-1)/(cos(w*Delta))
    Glist.append(G)
    Deltalist.append(Delta)
        
        
for iDelta in np.arange(0.001, 0.05, 0.005):
    iG = (3*iw*tau)-(iw**3*tau**3)/sin(iw*iDelta)
    iGlist.append(iG)
    iDeltalist.append(iDelta)
        
fig, axes = plt.subplots(1, 3,figsize=(20, 5))

axes[0].plot(Deltalist,Glist)
axes[0].set_title('dependency of G on the delay Delta - in R')
axes[0].set_ylabel('G')
axes[0].set_xlabel('Delta')


axes[1].plot(iDeltalist,iGlist)
axes[1].set_title('dependency of G on the delay Delta - in C')           
axes[1].set_ylabel('iG')
axes[1].set_xlabel('iDelta')

axes[2].plot(Deltalist,Glist)
axes[2].plot(iDeltalist,iGlist)
axes[2].set_ylabel('G')
axes[2].set_xlabel('Delta')
axes[2].set_title("Both");


plt.show()

# %%
def equaR(W,tau):
    tDeltalist=[]
    tGlist=[]
    
    for p in np.arange(0.001, 0.1, 0.001): #p=delay
        tG = (3*W**2*tau**2-1)/(cos(W*p))
        tGlist.append(tG)
        tDeltalist.append(p)
    return plt.plot(tDeltalist,tGlist,label='stau:'+ str(tau))
    
    
def equaC(iW,tau):
    itDeltalist=[]
    itGlist=[]
    
    for v in np.arange(0.001, 0.1, 0.001): # v=delay
        itG = (3*iW*tau)-(iW**3*tau**3)/sin(iW*v)
        itGlist.append(itG)
        itDeltalist.append(v)
    return plt.plot(itDeltalist,itGlist,label='stau:'+ str(tau))

# %%
for tau in np.arange(0.001,0.03,0.005):
    equaR(60,tau)


plt.ylabel('Gt')
plt.xlabel('Delta')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid()
plt.show()

# %%
for tau in np.arange(0.001,0.03,0.005):
    equaC(22,tau)

plt.ylabel('Gt')
plt.xlabel('Delta')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid()
plt.show()
