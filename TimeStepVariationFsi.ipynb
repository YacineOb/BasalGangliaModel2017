# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # Time_step=0.01 ms

# %%
x=np.load('timestepstudy/2017-05-09-16:33:29/GpeMsn_Activities.npy')
np.load('timestepstudy/2017-05-09-16:33:29/MsnFsi_Activities.npy')
np.load('timestepstudy/2017-05-09-16:33:29/FsiGpe_Activities.npy')
np.load('timestepstudy/2017-05-09-16:33:29/Msn_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:33:29/Gpe_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:33:29/Fsi_Inputs.npy')
# Out:
# array([[ 13.],
#        [ 13.],
#        [ 13.],
#        ...,
#        [  3.],
#        [  3.],
#        [  3.]])

# %% [markdown]
# # Time_step=0.05 ms

# %%
y=np.load('timestepstudy/2017-05-09-16:33:47/GpeMsn_Activities.npy')
np.load('timestepstudy/2017-05-09-16:33:47/MsnFsi_Activities.npy')
np.load('timestepstudy/2017-05-09-16:33:47/FsiGpe_Activities.npy')
np.load('timestepstudy/2017-05-09-16:33:47/Msn_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:33:47/Gpe_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:33:47/Fsi_Inputs.npy')
# Out:
# array([[ 13.],
#        [ 13.],
#        [ 13.],
#        ...,
#        [  3.],
#        [  3.],
#        [  3.]])

# %% [markdown]
# # Time_step=0.1 ms

# %%
z=np.load('timestepstudy/2017-05-09-16:34:33/GpeMsn_Activities.npy')
np.load('timestepstudy/2017-05-09-16:34:33/MsnFsi_Activities.npy')
np.load('timestepstudy/2017-05-09-16:34:33/FsiGpe_Activities.npy')
np.load('timestepstudy/2017-05-09-16:34:33/Msn_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:34:33/Gpe_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:34:33/Fsi_Inputs.npy')
# Out:
# array([[ 13.],
#        [ 13.],
#        [ 13.],
#        ...,
#        [  3.],
#        [  3.],
#        [  3.]])

# %% [markdown]
# # Time_step=0.5 ms

# %%
a=np.load('timestepstudy/2017-05-09-16:34:43/GpeMsn_Activities.npy')
np.load('timestepstudy/2017-05-09-16:34:43/MsnFsi_Activities.npy')
np.load('timestepstudy/2017-05-09-16:34:43/FsiGpe_Activities.npy')
np.load('timestepstudy/2017-05-09-16:34:43/Msn_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:34:43/Gpe_Inputs.npy')
np.load('timestepstudy/2017-05-09-16:34:43/Fsi_Inputs.npy')
# Out:
# array([[ 13.],
#        [ 13.],
#        [  3.],
#        ...,
#        [  3.],
#        [  3.],
#        [  3.]])

# %%
#  moyenne, la deviation standard(test statistiques)

x1=x[::5] - y
y1=np.arange(0,len(y),1)




plt.plot(y1,x1)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.01 vs 0.05')
plt.show()

x1=x[::10] - z

z1=np.arange(0,len(z),1)
plt.plot(z1,x1)
plt.title('0.01 vs 0.1')
plt.show()

x1=x[::50] - a

a1=np.arange(0,len(a),1)
plt.plot(a1,x1)
plt.title('0.01 vs 0.5')
plt.show()

#=======================================================


y2=y[::2] - z
y1=np.arange(0,len(z),1)

plt.plot(y1,y2)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.05 vs 0.1')
plt.show()


y3=y[::10] - a
z1=np.arange(0,len(a),1)

plt.plot(z1,y3)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.05 vs 0.5')
plt.show()

z2=z[::5] - a
a1=np.arange(0,len(a),1)

plt.plot(a1,z2)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.1 vs 0.5')
plt.show()

# %%
#  moyenne, la deviation standard(test statistiques)

x1=(x[::5] - y)**2
y1=np.arange(0,len(y),1)




plt.plot(y1,x1)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.01 vs 0.05')
plt.show()

x1=(x[::10] - z)**2

z1=np.arange(0,len(z),1)
plt.plot(z1,x1)
plt.title('0.01 vs 0.1')
plt.show()

x1=(x[::50] - a)**2

a1=np.arange(0,len(a),1)
plt.plot(a1,x1)
plt.title('0.01 vs 0.5')
plt.show()

#=======================================================


y2=(y[::2] - z)**2
y1=np.arange(0,len(z),1)

plt.plot(y1,y2)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.05 vs 0.1')
plt.show()


y3=(y[::10] - a)**2
z1=np.arange(0,len(a),1)

plt.plot(z1,y3)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.05 vs 0.5')
plt.show()

z2=(z[::5] - a)**2
a1=np.arange(0,len(a),1)

plt.plot(a1,z2)
plt.xlabel('number of step')
plt.ylabel('error')
plt.title('0.1 vs 0.5')
plt.show()
