# %%
import numpy as np
from matplotlib import pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

# %%
def plot(fignum,x,y,title='title',yax='y Axis',xax='x Axis'):
    plt.figure(fignum,figsize=(15,10))
    plt.plot(x,y,label=r'$\tau_{GpeMsn}$ = ' + str(int(i*1000)) + ' ms')
    plt.grid()
    plt.title(title,fontsize=20)
    plt.ylabel(yax,fontsize=18)
    plt.xlabel(xax,fontsize=18)
    plt.legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size':15})

# %%
i=0.020
a,b,d=dict(),dict(),dict()


a[i]=np.load('DiagramFsi/NewProcess/{0:.{1}f}_delta.npy'.format(i,3))
b[i]=np.load('DiagramFsi/NewProcess/{0:.{1}f}_frequency.npy'.format(i,3))
d[i]=np.load('DiagramFsi/NewProcess/{0:.{1}f}_weight.npy'.format(i,3))
      # Delay & FREQ
plot(1,a[i]*1000,b[i],"Oscillation frequency over the delay",'Oscillation frequency (Spikes/s)',r'$\Delta$ (ms)')
plt.plot(10, 16.7, marker='x', markersize=20, color="red",mew=4)
plt.plot(45, 7, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(100, 4, marker='x', markersize=20, color="green",mew=4)
plt.plot(60, 5.8, marker='x', markersize=20, color="purple",mew=4)
plt.plot(3, 26.5, marker='x', markersize=20, color="magenta",mew=4)
plt.plot(1, 34.5, marker='x', markersize=20, color="black",mew=4,label="experimental results")
plt.plot(2.5, 28.5, marker='x', markersize=20, color="yellow",mew=4)
plt.plot(6, 21, marker='x', markersize=20, color="yellow",mew=4)
plt.plot(25, 10.2, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(80, 4.7, marker='x', markersize=20, color="red",mew=4)
plt.plot(0.3, 37.7, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(30, 9.2, marker='x', markersize=20, color="magenta",mew=4)
plt.plot(18, 12.5, marker='x', markersize=20, color="black",mew=4)
plt.plot(1.5, 31.5, marker='x', markersize=20, color="green",mew=4)

plt.legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size':15})
#plt.savefig('P{}.png'.format('FD'),dpi=300,bbox_inches='tight')

    # G & FREQ
plot(2,d[i],b[i],"Oscillation frequency over Critical Weight",'Oscillation frequency (Spikes/s)','Critical Weight (AU)')
plt.plot(2.98, 16.7, marker='x', markersize=20, color="red",mew=4)
plt.plot(1.38, 7, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(1.1, 4, marker='x', markersize=20, color="green",mew=4)
plt.plot(1.25, 5.8, marker='x', markersize=20, color="purple",mew=4)
plt.plot(5.9, 26.5, marker='x', markersize=20, color="magenta",mew=4)
plt.plot(9.78, 34.5, marker='x', markersize=20, color="black",mew=4,label="experimental results")
plt.plot(6.7, 28.5, marker='x', markersize=20, color="yellow",mew=4)
plt.plot(4.1, 21, marker='x', markersize=20, color="yellow",mew=4)
plt.plot(1.8, 10.2, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(1.15, 4.7, marker='x', markersize=20, color="red",mew=4)
plt.plot(11.8, 37.7, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(1.65, 9.2, marker='x', markersize=20, color="magenta",mew=4)
plt.plot(2.2, 12.5, marker='x', markersize=20, color="black",mew=4)
plt.plot(8, 31.5, marker='x', markersize=20, color="green",mew=4)

plt.legend(bbox_to_anchor=(0.98, 0.02),loc=4, borderaxespad=0., prop={'size':15})
#plt.savefig('P{}.png'.format('FG'),dpi=300,bbox_inches='tight')

    # Delay & G
plot(3,a[i]*1000,d[i],"Critical Weight over the delay",'Critical Weight (AU)',r'$\Delta$ (ms)')
plt.plot(10, 2.98, marker='x', markersize=20, color="red",mew=4)
plt.plot(45, 1.38, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(100, 1.1, marker='x', markersize=20, color="green",mew=4)
plt.plot(60, 1.25, marker='x', markersize=20, color="purple",mew=4)
plt.plot(3, 5.9, marker='x', markersize=20, color="magenta",mew=4)
plt.plot(1, 9.78, marker='x', markersize=20, color="black",mew=4,label="experimental results")
plt.plot(2.5,6.7, marker='x', markersize=20, color="yellow",mew=4)
plt.plot(6, 4.1, marker='x', markersize=20, color="yellow",mew=4)
plt.plot(25, 1.8, marker='x', markersize=20, color="purple",mew=4)
plt.plot(80, 1.15, marker='x', markersize=20, color="red",mew=4)
plt.plot(0.3, 11.8, marker='x', markersize=20, color="cyan",mew=4)
plt.plot(30,1.65, marker='x', markersize=20, color="magenta",mew=4)
plt.plot(18, 2.2, marker='x', markersize=20, color="black",mew=4)
plt.plot(1.5,8, marker='x', markersize=20, color="green",mew=4)

plt.legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size':15})
#plt.savefig('P{}.png'.format('GD'),dpi=300,bbox_inches='tight')


plt.show()

# %%
print("delay",a[i])  
print(a[i][20])
print("frequency",b[i])
print(b[i][20])
# Out:
# delay [ 0.     0.001  0.002  0.003  0.004  0.005  0.006  0.007  0.008  0.009
#   0.01   0.011  0.012  0.013  0.014  0.015  0.016  0.017  0.018  0.019
#   0.02   0.021  0.022  0.023  0.024  0.025  0.026  0.027  0.028  0.029
#   0.03   0.031  0.032  0.033  0.034  0.035  0.036  0.037  0.038  0.039
#   0.04   0.041  0.042  0.043  0.044  0.045  0.046  0.047  0.048  0.049
#   0.05   0.051  0.052  0.053  0.054  0.055  0.056  0.057  0.058  0.059
#   0.06   0.061  0.062  0.063  0.064  0.065  0.066  0.067  0.068  0.069
#   0.07   0.071  0.072  0.073  0.074  0.075  0.076  0.077  0.078  0.079
#   0.08   0.081  0.082  0.083  0.084  0.085  0.086  0.087  0.088  0.089
#   0.09   0.091  0.092  0.093  0.094  0.095  0.096  0.097  0.098  0.099]
# 0.02
# frequency [ 38.98484006  32.84445331  28.93539969  26.11761349  23.9444779
#   22.19487355  20.74340891  19.51228136  18.45000238  17.52080171
#   16.69886695  15.96499395  15.30453184  14.70606631  14.16054449
# ...

# %%
fig, ax1 = plt.subplots(figsize=(15,10))

ax1.plot(a[i]*1000, d[i], 'k-')

#ax1.set_xlim(0, 0.1)
ax1.set_xlabel(r'$\Delta$ (ms)')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Critical Weight Gc (AU)', color='b')
ax1.tick_params('y', colors='b')
ax2 = ax1.twiny()

ax2.plot(d[i], a[i], 'r-')

ax2.invert_xaxis()
ax2.set_xlabel('frequency', color='r')
ax2.tick_params('x', colors='r')
fig.tight_layout()


ax2.text(38,1 , 'Fixed Point', style='italic',
        bbox={'facecolor':'white', 'alpha':0.4, 'pad':10}, fontsize=20)
ax2.fill_between(b[i], 0, d[i],color='blue',interpolate=True, alpha=0.2)

ax2.text(20,7 , 'Oscillatory regime', style='italic',
        bbox={'facecolor':'white', 'alpha':0.4, 'pad':10}, fontsize=20)
ax2.fill_between(b[i],d[i],15, interpolate=True, color='red',alpha=0.2)

plt.show()
