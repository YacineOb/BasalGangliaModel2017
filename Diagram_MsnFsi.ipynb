# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def plot(fignum,x,y,title='title',yax='y Axis',xax='x Axis'):
    plt.figure(fignum,figsize=(15,10))
    plt.plot(x,y,label='tauGpeMsn =' + str(i))
    plt.grid()
    plt.title(title)
    plt.ylabel(yax)
    plt.xlabel(xax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., prop={'size':15})

# %%
lim=np.arange(0.005,0.030,0.005)
a,b,d=dict(),dict(),dict()

for i in lim:
    a[i]=np.load('DiagramFsi/NewProcess/{0:.{1}f}_delta.npy'.format(i,3))
    b[i]=np.load('DiagramFsi/NewProcess/{0:.{1}f}_frequency.npy'.format(i,3))
    d[i]=np.load('DiagramFsi/NewProcess/{0:.{1}f}_weight.npy'.format(i,3))
    
    plot(1,a[i],b[i],"Oscillation frequency over the Delay (Delta)",'f (Oscillation frequency)','Delta (Delay)')
    plot(2,d[i],b[i],"Oscillation frequency over Critical Weight",'f (Oscillation frequency)','Gc (Critical Weight)')
    plot(3,a[i],d[i],"Critical Weight over the Delay (Delta)",'Gc (Critical Weight)','Delta (Delay)')



plt.show()
