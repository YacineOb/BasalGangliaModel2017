# %%
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib 
from scipy import interpolate
from scipy.interpolate import spline
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20)
plt.rcParams["axes.labelweight"] = "bold"

# %%
plt.figure(figsize=(15,10))
plt.ylabel('G_MSN_D1_to_SNr',fontsize=25,fontweight='bold')
plt.xlabel('G_MSN_D2_to_GPe',fontsize=25,fontweight='bold')

#=====================================Delta_Total=16ms=====================================

plt.plot(1, 2.7, marker='o', markersize=15, color="red",mew=1)
plt.plot(1.20, 2.4, marker='o', markersize=15, color="red",mew=1)
plt.plot(1.5, 2.2, marker='o', markersize=15, color="red",mew=1)
plt.plot(1.7, 2.0, marker='o', markersize=15, color="red",mew=1)
plt.plot(2, 1.8, marker='o', markersize=15, color="red",mew=1)
plt.plot(2.3, 1.6, marker='o', markersize=15, color="red",mew=1)
plt.plot(2.5, 1.5, marker='o', markersize=15, color="red",mew=1)
plt.plot(2.7, 1.4, marker='o', markersize=15, color="red",mew=1)
plt.plot(3, 1.32, marker='o', markersize=15, color="red",mew=1)
plt.plot(3.2, 1.27, marker='o', markersize=15, color="red",mew=1)
plt.plot(3.5, 1.2, marker='o', markersize=15, color="red",mew=1,label="experimental results : 17Hz: deltaT:16ms")
plt.plot(3.7, 1.15, marker='o', markersize=15, color="red",mew=1)
plt.plot(4, 1.07, marker='o', markersize=15, color="red",mew=1)
plt.plot(4.30, 1, marker='o', markersize=15, color="red",mew=1)
#=========================================================================================
#=====================================Delta_Total=11ms====================================
plt.plot(1, 3.7, marker='^', markersize=15, color="green",mew=1)
plt.plot(1.20, 3.25, marker='^', markersize=15, color="green",mew=1)
plt.plot(1.5, 2.90, marker='^', markersize=15, color="green",mew=1)
plt.plot(1.7, 2.65, marker='^', markersize=15, color="green",mew=1)
plt.plot(2, 2.40, marker='^', markersize=15, color="green",mew=1)
plt.plot(2.3, 2.20, marker='^', markersize=15, color="green",mew=1)
plt.plot(2.5, 2.05, marker='^', markersize=15, color="green",mew=1)
plt.plot(2.7, 1.95, marker='^', markersize=15, color="green",mew=1)
plt.plot(3, 1.80, marker='^', markersize=15, color="green",mew=1)
plt.plot(3.2, 1.70, marker='^', markersize=15, color="green",mew=1)
plt.plot(3.5, 1.65, marker='^', markersize=15, color="green",mew=1,label="experimental results : 21.8Hz: deltaT:11ms")
plt.plot(3.7, 1.55, marker='^', markersize=15, color="green",mew=1)
plt.plot(4, 1.45, marker='^', markersize=15, color="green",mew=1)
plt.plot(5, 1.20, marker='^', markersize=15, color="green",mew=1)
plt.plot(6.15, 1, marker='^', markersize=15, color="green",mew=1)
#=========================================================================================
#=====================================Delta_Total=6ms====================================

plt.plot(1, 5.7, marker='x', markersize=15, color="blue",mew=1)
plt.plot(1.20, 5.1, marker='x', markersize=15, color="blue",mew=1)
plt.plot(1.5, 4.5, marker='x', markersize=15, color="blue",mew=1)
plt.plot(1.7, 4.1, marker='x', markersize=15, color="blue",mew=1)
plt.plot(2, 3.65, marker='x', markersize=15, color="blue",mew=1)
plt.plot(2.3, 3.35, marker='x', markersize=15, color="blue",mew=1)
plt.plot(2.5, 3.175, marker='x', markersize=15, color="blue",mew=1)
plt.plot(2.7, 3.00, marker='x', markersize=15, color="blue",mew=1)
plt.plot(3, 2.75, marker='x', markersize=15, color="blue",mew=1)
plt.plot(3.2, 2.65, marker='x', markersize=15, color="blue",mew=1)
plt.plot(3.5, 2.45, marker='x', markersize=15, color="blue",mew=1,label="experimental results : 30Hz: deltaT:6ms")
plt.plot(3.7, 2.35, marker='x', markersize=15, color="blue",mew=1)
plt.plot(4, 2.25, marker='x', markersize=15, color="blue",mew=1)
plt.plot(5, 1.85, marker='x', markersize=15, color="blue",mew=1)
plt.plot(6, 1.55, marker='x', markersize=15, color="blue",mew=1)
plt.plot(7, 1.35, marker='x', markersize=15, color="blue",mew=1)
plt.plot(8, 1.25, marker='x', markersize=15, color="blue",mew=1)
plt.plot(9, 1.15, marker='x', markersize=15, color="blue",mew=1)
plt.plot(10.1, 1, marker='x', markersize=15, color="blue",mew=1)
#=========================================================================================


x = np.array([1,1.20,1.5,1.7,2,2.3,2.5,2.7,3,3.2,3.5,3.7,4,5,6,7,8,9,10])
y = np.array([5.7,5.1,4.5,4.1,3.65,3.35,3.175,3.00,2.75,2.65,2.45,2.35,2.25,1.85,1.55,1.35,1.25,1.15,1])

x1 = np.array([1,1.20,1.5,1.7,2,2.3,2.5,2.7,3,3.2,3.5,3.7,4,5,6])
y1 = np.array([3.7,3.25,2.90,2.65,2.40,2.20,2.05,1.95,1.80,1.70,1.65,1.55,1.45,1.20,1])

x2 = np.array([1,1.20,1.50,1.7,2,2.3,2.5,2.7,3,3.2,3.5,3.7,4,4.30])
y2 = np.array([2.7,2.4,2.2,2.0,1.8,1.6,1.5,1.4,1.32,1.27,1.2,1.15,1.07,1])


f = interpolate.interp1d(x, y,'cubic')
f1= interpolate.interp1d(x1, y1,'cubic')
f2= interpolate.interp1d(x2, y2,'cubic')

xnew = x
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(xnew, ynew, '--',color="blue")

xnew1 = x1
ynew1 = f1(xnew1)   # use interpolation function returned by `interp1d`
plt.plot(xnew1, ynew1, '--',color="green")

xnew2 = x2
ynew2 = f2(xnew2)   # use interpolation function returned by `interp1d`
plt.plot(xnew2, ynew2, '--',color="red")




plt.tight_layout()


plt.legend(bbox_to_anchor=(0.98, 0.98), loc=1, borderaxespad=0., prop={'size':15})

plt.text(1,1 , 'Steady state', style='italic',
        bbox={'facecolor':'white', 'pad':10}, fontsize=15,fontweight='bold')

plt.text(8,4 , 'Oscillatory regime', style='italic',
        bbox={'facecolor':'white', 'pad':10}, fontsize=15,fontweight='bold')

plt.savefig('DataTha/PhaseDiagTha.png',dpi=150,bbox_inches='tight')

plt.show()

# %%
plt.figure(figsize=(15,10))
plt.ylabel('Oscillations frequency (Hz)',fontsize=25,fontweight='bold')
plt.xlabel('Delai (millisecondes)',fontsize=25,fontweight='bold')

#=====================================Delta_Total=16ms=====================================
plt.plot(0.1, 48.8, marker='x', markersize=15, color="purple",mew=1)
plt.plot(1.5, 37.2, marker='x', markersize=15, color="purple",mew=1)
plt.plot(2.5, 33.2, marker='x', markersize=15, color="purple",mew=1)
plt.plot(4.5, 25.8, marker='x', markersize=15, color="purple",mew=1)
plt.plot(6, 23.2, marker='x', markersize=15, color="purple",mew=1)
plt.plot(8, 19.8, marker='x', markersize=15, color="purple",mew=1)
plt.plot(10, 17.4, marker='x', markersize=15, color="purple",mew=1)
plt.plot(20, 12.2, marker='x', markersize=15, color="purple",mew=1)
plt.plot(30, 10.2, marker='x', markersize=15, color="purple",mew=1)
plt.plot(40, 8.4, marker='x', markersize=15, color="purple",mew=1)
plt.plot(50, 6.6, marker='x', markersize=15, color="purple",mew=1)
plt.plot(60, 6.4, marker='x', markersize=15, color="purple",mew=1)
plt.plot(80, 5.4, marker='x', markersize=15, color="purple",mew=1)
plt.plot(100, 4.6, marker='x', markersize=15, color="purple",mew=1)
plt.plot(120, 4.4, marker='x', markersize=15, color="purple",mew=1)

x = np.array([0.1,1.5,2.5,4.5,6,8,10,20,30,40,50,60,80,100,120])
y = np.array([48.8,37.2 ,33.2 ,25.8 ,23.2 ,19.8 ,17.4 ,12.2 ,10.2 ,8.4,7.3,6.4 ,5.4 ,4.6 ,4.4])

f = interpolate.interp1d(x, y,kind='cubic')

xnew = x
ynew = f(xnew)   # use interpolation function returned by `interp1d`
xnew2 = np.linspace(x.min(),x.max(),300) #300 represents number of points to make between T.min and T.max
power_smooth = spline(xnew,ynew,xnew2)
plt.plot(x, y, 'o', xnew2, power_smooth, '--',markersize=15, color="purple",mew=1)

plt.tight_layout()
plt.savefig('DataTha/OscdeltaTha.png',dpi=150,bbox_inches='tight')
plt.show()
# Out:
# /home/imn/.pyenv/versions/3.5.2/lib/python3.5/site-packages/ipykernel/__main__.py:30: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [raw]
# x = np.array([0.1,1.5,2.5,4.5,6,8,10,20,30,40,50,60,80,100,120])
# y = np.array([48.8,37.2 ,33.2 ,25.8 ,23.2 ,19.8 ,17.4 ,12.2 ,10.2 ,8.4,6.6 ,6.4 ,5.4 ,4.6 ,4.4])
#
# f = interpolate.interp1d(x, y)
#
# xnew = x
# ynew = f(xnew)   # use interpolation function returned by `interp1d`
# plt.plot(x, y, 'o', xnew, ynew, '-')
# plt.show()
